# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Telco-Customer-Churn.xlsx - Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Compare churn count with respect to gender.

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df['gender'],hue=df['Churn'])
plt.xlabel('Gender',fontweight='bold',fontsize=15)
plt.ylabel('Churn Count',fontweight='bold',fontsize=15)
plt.title('Gender vs Churn',fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gender vs Churn')

# %% [markdown]
# # Find out how many female senior citizens there in the dataset

# %%
fsc=df[(df['gender']=='Female') & (df['SeniorCitizen']==1)]

# %%
fsc.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 30  3841-NFECX  Female              1     Yes         No      71          Yes
# 50  8012-SOUDQ  Female              1      No         No      43          Yes
# 52  6575-SUVOI  Female              1     Yes         No      25          Yes
# 53  7495-OOKFY  Female              1     Yes         No       8          Yes
# 54  4667-QONEA  Female              1     Yes        Yes      60          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 30           Yes     Fiber optic            Yes  ...              Yes
# 50           Yes     Fiber optic             No  ...               No
# 52           Yes             DSL            Yes  ...               No
# 53           Yes     Fiber optic             No  ...               No
# 54            No             DSL            Yes  ...              Yes
#
# ...

# %%
fsc['gender'].count()
print('Number of female senior citizens there in the dataset =',fsc['gender'].count())
# Out:
# Number of female senior citizens there in the dataset = 568

# %%
plt.figure(figsize=(6,10))
sns.countplot(x=fsc['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# # Compare 'tenure' with 'Total Charges'

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['tenure'],df['TotalCharges'],s=10,marker='^')
plt.title('Tenure with Total Charges',fontweight='bold',fontsize=20)
plt.xlabel('Tenure',fontsize=15)
plt.ylabel('TotalCharges',fontsize=15)
# Out:
# Text(0, 0.5, 'TotalCharges')

# %% [markdown]
# # Find out which contract is preferred by the senior citizen.

# %%
cz=df[df['SeniorCitizen']==1]

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=cz['Contract'],hue=cz['Contract'])
plt.title('contract preferred by the senior citizen',fontweight='bold',fontsize=20)
plt.xlabel('Contract Type',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# # Comment on your finds on Payment Method

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df['PaymentMethod'])
plt.grid()
plt.show()

# %%
# payment method preferred based on gender

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df['PaymentMethod'],hue=df['gender'])
plt.grid()
plt.show()

# %%
#payment method prefferd by senior citizen

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=cz['PaymentMethod'])
plt.grid()
plt.show()

# %%
#payment method prefferd by senior citizen based on gender

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=cz['PaymentMethod'],hue=cz['gender'])
plt.grid()
plt.show()

# %%
#payment method preffered based on contract type

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df['PaymentMethod'],hue=df['Contract'])
plt.grid()
plt.show()
